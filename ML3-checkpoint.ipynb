# %%
#phase 3 merging user ratings data set
import pandas as pd           #importing pandas
df = pd.read_csv (r'C:\Users\Anju\Desktop\appstore.csv')
c=df.Genres.value_counts
u=[]

freq={}
def CountFrequency(my_list):
   
    for item in my_list:
        if (item in freq): 
            freq[item] += 1
        else: 
            freq[item] = 1
  
    for key, value in freq.items():
        print ("% s : % d"%(key, value))
    # Driver function 
if __name__ == "__main__": 
    my_list=u
import matplotlib.pyplot as plt 
gc=df[df['Average User Rating']>4]                              #3851 rows have counti.eavg user ratings greater than 4 
print("***********",gc)
print(gc.shape)
for i in gc.Genres:                                         #conversion of strings in genres to lists
    c=i.split(", ")
    c.remove('Games')                                        # removing games from the lists
    if(('Strategy' in c)==True):
        c.remove('Strategy')
        print(c)
        u+=c
print('wtf')
CountFrequency(u)
from collections import OrderedDict
d_descending = OrderedDict(sorted(freq.items(), key=lambda kv: kv[1],reverse=True))
print(d_descending)
plt.bar(list(freq.keys()),freq.values(),color='g')
plt.show() 
plt.bar(list(d_descending.keys()),d_descending.values(),color='blue')
plt.show()
df.plot(kind='scatter',x='User Rating Count', y='Price', rot=70)
plt.show()
df.plot(kind='scatter',x='Average User Rating', y='Price', rot=70)
plt.show()
# Out:
# ***********                                                      URL          ID  \
# 59     https://apps.apple.com/us/app/wedding-dash-del...   303337299
# 78     https://apps.apple.com/us/app/sallys-spa/id307...   307132353
# 82     https://apps.apple.com/us/app/shredder-chess/i...   308032437
# 91     https://apps.apple.com/us/app/pocket-tanks-del...   311466554
# 118      https://apps.apple.com/us/app/chess/id319305999   319305999
# 123    https://apps.apple.com/us/app/checkers/id32102...   321026028
# 124    https://apps.apple.com/us/app/checkers/id32102...   321026028
# 127    https://apps.apple.com/us/app/pixel-starships/...   321756558
# 139    https://apps.apple.com/us/app/sudoku-deluxe/id...   324335340
# 142    https://apps.apple.com/us/app/phoenix-emperor-...   324538716
# 156    https://apps.apple.com/us/app/chess-play-learn...   329218549
# 160    https://apps.apple.com/us/app/slideswipe/id329...   329911028
# ...
